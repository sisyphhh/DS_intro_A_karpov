# %%
import pandas as pd
import numpy as np
import seaborn as sns
directory_1='C:\\Users\\poll\\zzz_Data_science\\1_intro_TO_DS_karpov\\'

# %% [markdown]
# # 1.7 ==========================================================

# %%
stud_perform=pd.read_csv(directory_1+'PD_pract\\StudentsPerformance.csv')

# %%
stud_perform.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
stud_perform = stud_perform \
    .rename(columns = 
               {'parental level of education':'parental_level_of_education',
                'test preparation course':'test_preparation_course',
                'math score':'math_score',
                'reading score':'reading_score',
                'writing score':'writing_score'})
stud_perform.head()
# Out:
#    gender race/ethnicity parental_level_of_education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test_preparation_course  math_score  reading_score  writing_score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
stud_perform.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
stud_perform['math_score'].hist();

# %%
stud_perform.plot.scatter(x='math_score',y='reading_score');

# %%
ax = sns.lmplot(x='math_score',y='reading_score',hue='gender',data=stud_perform,fit_reg=False)
ax.set_xlabels('Math score')
ax.set_ylabels('Reading score')

# %% [markdown]
# ## Task1

# %%
incom=pd.read_csv(directory_1+'PD_pract\\income.csv')
incom.head()
# Out:
#             income
# 2018-11-30      20
# 2018-12-31      60
# 2019-01-31     180
# 2019-02-28     380
# 2019-03-31     660

# %%
#incom['income'].plot()
sns.lineplot(x=incom.index,y=incom.income)

# %% [markdown]
# ## Task2 - special dataset for time
# ### show plot of dots probability 2 variables x&y. Your anwer is the number of clasters

# %%
#,index_col=0 first column become indexes
tmp_data=pd.read_csv(directory_1+'PD_pract\\dataset_209770_6.txt',sep=' ')
tmp_data.head()
# Out:
#             x           y
# 0  792.996495  197.013940
# 1  786.646487  195.608510
# 2  411.246239  889.874430
# 3  411.362216  909.549510
# 4  104.552032  408.417747

# %%
#ax = sns.scatterplot(x='x',y='y',data=tmp_data)
ax = sns.lmplot(x='x',y='y',data=tmp_data,fit_reg=False)

# %% [markdown]
# ## Task3
# ### make heatmap between types

# %%
#first column become indexes
genom=pd.read_csv(directory_1+'PD_pract\\genome_matrix.csv',index_col=0)
genom.head()
# Out:
#           species0  species1  species2  species3  species4
# species0  0.536029  0.920292  0.679708  0.840606  0.430842
# species1  0.920292  0.862417  0.887593  0.769754  0.203214
# species2  0.679708  0.887593  0.595156  0.003435  0.096052
# species3  0.840606  0.769754  0.003435  0.458870  0.029251
# species4  0.430842  0.203214  0.096052  0.029251  0.642109

# %%
ax=sns.heatmap(genom,cmap='viridis')
ax.xaxis.set_ticks_position('top')
ax.xaxis.set_tick_params(rotation=90)

# %% [markdown]
# ## Task4 - dota heroes - plot hist that shows many heroes for fix number of roles set are

# %%
#,index_col=0 first column become indexes
dota=pd.read_csv(directory_1+'PD_pract\\dota_hero_stats.csv')
dota.head()
# Out:
#    Unnamed: 0 attack_type  id  legs  localized_name  \
# 0           0       Melee   1     2       Anti-Mage
# 1           1       Melee   2     2             Axe
# 2           2      Ranged   3     4            Bane
# 3           3       Melee   4     2     Bloodseeker
# 4           4      Ranged   5     2  Crystal Maiden
#
#                            name primary_attr  \
# 0        npc_dota_hero_antimage          agi
# 1             npc_dota_hero_axe          str
# 2            npc_dota_hero_bane          int
# 3     npc_dota_hero_bloodseeker          agi
# 4  npc_dota_hero_crystal_maiden          int
#
#                                                roles
# 0                       ['Carry', 'Escape', 'Nuker']
# 1    ['Initiator', 'Durable', 'Disabler', 'Jungler']
# 2        ['Support', 'Disabler', 'Nuker', 'Durable']
# 3  ['Carry', 'Disabler', 'Jungler', 'Nuker', 'Ini...
# 4        ['Support', 'Disabler', 'Nuker', 'Jungler']

# %%
#so all pd line in roles is like = "['a','b','c',...]"
#and all series role is like = ["['a','b','c',...]", "[...]",...]
'''
0 - ['a','b','c',...]
1 - [...]
...
'''
#first of all we cut in str '[]' and then we form a list ->'['a']'->['a']
ans=dota.roles.str[1:-1].str.split(',')
print(ans)
print(ans[0],len(ans[0]),type(ans[0]))
#print(type(ans[0]))
##ans.len()

answer=[]
for i in ans:
    answer.append(len(i))
# Out:
# 0                         ['Carry',  'Escape',  'Nuker']
# 1      ['Initiator',  'Durable',  'Disabler',  'Jungl...
# 2         ['Support',  'Disabler',  'Nuker',  'Durable']
# 3      ['Carry',  'Disabler',  'Jungler',  'Nuker',  ...
# 4         ['Support',  'Disabler',  'Nuker',  'Jungler']
#                              ...
# 112      ['Carry',  'Escape',  'Disabler',  'Initiator']
# 113        ['Support',  'Nuker',  'Disabler',  'Escape']
# 114    ['Carry',  'Nuker',  'Disabler',  'Durable',  ...
# 115        ['Support',  'Nuker',  'Disabler',  'Escape']
# 116     ['Carry',  'Initiator',  'Disabler',  'Durable']
# Name: roles, Length: 117, dtype: object
# ["'Carry'", " 'Escape'", " 'Nuker'"] 3 <class 'list'>

# %%
answer=pd.Series(answer)
answer.hist();

# %% [markdown]
# ## Task5 - flowers

# %%
#,index_col=0 first column become indexes
flower=pd.read_csv(directory_1+'PD_pract\\iris.csv',index_col=0)
#folwer.shape
flower = flower.rename(columns = 
               {'sepal length':'sepal_length',
                'sepal width':'sepal_width',
                'petal length':'petal_length',
                'petal width':'petal_width'})
flower.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width  species
# 0           5.1          3.5           1.4          0.2        0
# 1           4.9          3.0           1.4          0.2        0
# 2           4.7          3.2           1.3          0.2        0
# 3           4.6          3.1           1.5          0.2        0
# 4           5.0          3.6           1.4          0.2        0

# %%
#sns.set(style='darkgrid')
for column in flower:
    #print(column)
    sns.kdeplot(flower[column])
    #sns.distplot(flower[column])

# %%
sns.distplot(flower['petal_length'],vertical=1)

# %%
ax=sns.violinplot(x='petal_length',data=flower,orient='v',color='g')

# %% [markdown]
# ## Task6

# %%
flower.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width  species
# 0           5.1          3.5           1.4          0.2        0
# 1           4.9          3.0           1.4          0.2        0
# 2           4.7          3.2           1.3          0.2        0
# 3           4.6          3.1           1.5          0.2        0
# 4           5.0          3.6           1.4          0.2        0

# %%
ax=sns.pairplot(flower,hue='species')

# %%
ax=sns.heatmap(flower.corr(),annot=True,cmap='viridis')
ax.xaxis.set_ticks_position('top')
ax.xaxis.set_tick_params(rotation=90)
